# %%
import scipy.io
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np
# Out:
# /home/hyc_1/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
mat_1 = scipy.io.loadmat('HIQ1_2.mat')
mat_17 = scipy.io.loadmat('HIQ17_2.mat')

# %%
len(mat_1['atlas'][0])
# Out:
# 23

# %%
fig, ax = plt.subplots(figsize=(17,14))

im = ax.imshow(mat_1['connectivity']-mat_17['connectivity'],interpolation='none')
fig.colorbar(im,label='Valor de la resta')
#ax.set_xticks(np.linspace(0,60,num=len(mat_1['atlas'][0])),labels=mat_1['atlas'][0])
#ax.set_yticks(np.linspace(0,60,num=len(mat_1['atlas'][0])),labels=mat_1['atlas'][0])
ax.set_title('Resta de longitud media de tractos entre sujeto 1 y sujeto 17',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Resta de longitud media de tractos entre sujeto 1 y sujeto 17')

# %% [markdown]
# #### PLV
