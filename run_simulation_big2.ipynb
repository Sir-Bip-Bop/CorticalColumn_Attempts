# %%
import nest
import os
import network
import addons
import numpy as np
from network_params import net_dict
import network_params
from sim_params import sim_dict
from stimulus_params import stim_dict
# Out:
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.7.0
#  Built: Apr 15 2024 07:21:32
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.
# /home/hyc_1/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning:Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.

# %% [markdown]
# Initialize the network with simulation, network and stimulation parameters, then create and connect all nodes, and finally simulate. The times for a presimulation and the main simulation are taken independently. A presimulation is useful because the spike activity typically exhibits a startup transient. In benchmark simulations, this transient should be excluded from a time measurement of the state propagation phase. Besides, statistical measures of the spike activity should only be computed after the transient has passed.

# %%
record_synapses = False



bg_rate = np.linspace(5,20,int((20-5)/0.5))

number_trials = 1


path = "data_volt/"

for i in range(len(bg_rate)):
     if not os.path.exists(path + str(round(bg_rate[i],2))):
        os.makedirs(path + str(round(bg_rate[i],2)))
     for j in range(number_trials):
        nest.ResetKernel()

       
        net = network.Network(sim_dict, net_dict, stim_dict, path = "data_volt/" + str(round(bg_rate[i],2)) + "/trial_"+str(j) + "/", bg_rate= bg_rate[i])

        net.create(rate="random")
        net.connect()
    
        if record_synapses:
            data_synapses = addons.number_synapses(net.pops)
        record_synapses = False
    

        net.simulate(sim_dict["t_presim"])
        net.simulate(sim_dict["t_sim"])
        #raster_plot_interval = np.array([500, 900])
        #firing_rates_interval = np.array([500,60500])
        #pop_activity = net.evaluate(raster_plot_interval, firing_rates_interval,binned=True, plot=False)
# Out:
# Data will be written to: data_volt/5.0/trial_0/
#   Directory has been created.
#
#
# RNG seed: 55
# Total number of virtual processes: 10
# Creating neuronal populations.
#
# Feb 05 11:44:00 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Creating recording devices.
#   Creating voltmeters.
# Creating Poisson generators for background input.
# Connecting neuronal populations recurrently.
# NodeCollection(metadata=None, model=iaf_psc_exp, size=20683, first=1, last=20683)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5834, first=20684, last=26517)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=21915, first=26518, last=48432)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5479, first=48433, last=53911)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=4850, first=53912, last=58761)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=1065, first=58762, last=59826)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=14395, first=59827, last=74221)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=2948, first=74222, last=77169)
# Connecting Poisson generators for background input.
#
# Feb 05 11:44:11 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
# Simulating 500.0 ms.
#
# Feb 05 11:44:13 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 11:44:13 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 500
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 11:44:25 SimulationManager::run [Info]:
#     Simulation finished.
# Simulating 1000.0 ms.
#
# Feb 05 11:44:25 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 11:44:25 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 1000
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 11:44:55 SimulationManager::run [Info]:
#     Simulation finished.
# Data will be written to: data_volt/5.52/trial_0/
#   Directory has been created.
#
#
# RNG seed: 55
# Total number of virtual processes: 10
# Creating neuronal populations.
#
# Feb 05 11:44:55 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Creating recording devices.
#   Creating voltmeters.
# Creating Poisson generators for background input.
# Connecting neuronal populations recurrently.
# NodeCollection(metadata=None, model=iaf_psc_exp, size=20683, first=1, last=20683)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5834, first=20684, last=26517)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=21915, first=26518, last=48432)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5479, first=48433, last=53911)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=4850, first=53912, last=58761)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=1065, first=58762, last=59826)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=14395, first=59827, last=74221)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=2948, first=74222, last=77169)
# Connecting Poisson generators for background input.
#
# Feb 05 11:45:03 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
# Simulating 500.0 ms.
# Simulating 1000.0 ms.
#
# Feb 05 11:45:05 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 11:45:05 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 500
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 11:45:18 SimulationManager::run [Info]:
#     Simulation finished.
#
# Feb 05 11:45:18 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 11:45:18 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 1000
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 11:45:48 SimulationManager::run [Info]:
#     Simulation finished.
# Data will be written to: data_volt/6.03/trial_0/
#   Directory has been created.
#
#
# RNG seed: 55
# Total number of virtual processes: 10
# Creating neuronal populations.
#
# Feb 05 11:45:48 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Creating recording devices.
#   Creating voltmeters.
# Creating Poisson generators for background input.
# Connecting neuronal populations recurrently.
# NodeCollection(metadata=None, model=iaf_psc_exp, size=20683, first=1, last=20683)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5834, first=20684, last=26517)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=21915, first=26518, last=48432)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5479, first=48433, last=53911)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=4850, first=53912, last=58761)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=1065, first=58762, last=59826)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=14395, first=59827, last=74221)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=2948, first=74222, last=77169)
# Connecting Poisson generators for background input.
#
# Feb 05 11:45:56 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
# Simulating 500.0 ms.
#
# Feb 05 11:45:58 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 11:45:58 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 500
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 11:46:11 SimulationManager::run [Info]:
#     Simulation finished.
# Simulating 1000.0 ms.
#
# Feb 05 11:46:11 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 11:46:11 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 1000
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 11:46:40 SimulationManager::run [Info]:
#     Simulation finished.
# Data will be written to: data_volt/6.55/trial_0/
#   Directory has been created.
#
#
# RNG seed: 55
# Total number of virtual processes: 10
# Creating neuronal populations.
#
# Feb 05 11:46:41 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Creating recording devices.
#   Creating voltmeters.
# Creating Poisson generators for background input.
# Connecting neuronal populations recurrently.
# NodeCollection(metadata=None, model=iaf_psc_exp, size=20683, first=1, last=20683)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5834, first=20684, last=26517)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=21915, first=26518, last=48432)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5479, first=48433, last=53911)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=4850, first=53912, last=58761)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=1065, first=58762, last=59826)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=14395, first=59827, last=74221)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=2948, first=74222, last=77169)
# Connecting Poisson generators for background input.
# Simulating 500.0 ms.
#
# Feb 05 11:46:49 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
# Simulating 1000.0 ms.
#
# Feb 05 11:46:51 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 11:46:51 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 500
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 11:47:05 SimulationManager::run [Info]:
#     Simulation finished.
#
# Feb 05 11:47:05 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 11:47:05 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 1000
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 11:47:38 SimulationManager::run [Info]:
#     Simulation finished.
# Data will be written to: data_volt/7.07/trial_0/
#   Directory has been created.
#
#
# RNG seed: 55
# Total number of virtual processes: 10
# Creating neuronal populations.
#
# Feb 05 11:47:38 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Creating recording devices.
#   Creating voltmeters.
# Creating Poisson generators for background input.
# Connecting neuronal populations recurrently.
# NodeCollection(metadata=None, model=iaf_psc_exp, size=20683, first=1, last=20683)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5834, first=20684, last=26517)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=21915, first=26518, last=48432)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5479, first=48433, last=53911)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=4850, first=53912, last=58761)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=1065, first=58762, last=59826)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=14395, first=59827, last=74221)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=2948, first=74222, last=77169)
# Connecting Poisson generators for background input.
#
# Feb 05 11:47:47 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
# Simulating 500.0 ms.
# Simulating 1000.0 ms.
#
# Feb 05 11:47:49 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 11:47:49 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 500
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 11:48:03 SimulationManager::run [Info]:
#     Simulation finished.
#
# Feb 05 11:48:03 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 11:48:03 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 1000
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 11:48:36 SimulationManager::run [Info]:
#     Simulation finished.
# Data will be written to: data_volt/7.59/trial_0/
#   Directory has been created.
#
#
# RNG seed: 55
# Total number of virtual processes: 10
# Creating neuronal populations.
#
# Feb 05 11:48:36 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Creating recording devices.
#   Creating voltmeters.
# Creating Poisson generators for background input.
# Connecting neuronal populations recurrently.
# NodeCollection(metadata=None, model=iaf_psc_exp, size=20683, first=1, last=20683)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5834, first=20684, last=26517)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=21915, first=26518, last=48432)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5479, first=48433, last=53911)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=4850, first=53912, last=58761)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=1065, first=58762, last=59826)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=14395, first=59827, last=74221)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=2948, first=74222, last=77169)
# Connecting Poisson generators for background input.
# Simulating 500.0 ms.
#
# Simulating 1000.0 ms.
# Feb 05 11:48:46 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 11:48:48 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 11:48:48 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 500
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 11:49:03 SimulationManager::run [Info]:
#     Simulation finished.
#
# Feb 05 11:49:03 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 11:49:03 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 1000
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 11:49:37 SimulationManager::run [Info]:
#     Simulation finished.
# Data will be written to: data_volt/8.1/trial_0/
#   Directory has been created.
#
#
# RNG seed: 55
# Total number of virtual processes: 10
# Creating neuronal populations.
#
# Feb 05 11:49:38 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Creating recording devices.
#   Creating voltmeters.
# Creating Poisson generators for background input.
# Connecting neuronal populations recurrently.
# NodeCollection(metadata=None, model=iaf_psc_exp, size=20683, first=1, last=20683)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5834, first=20684, last=26517)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=21915, first=26518, last=48432)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5479, first=48433, last=53911)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=4850, first=53912, last=58761)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=1065, first=58762, last=59826)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=14395, first=59827, last=74221)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=2948, first=74222, last=77169)
# Connecting Poisson generators for background input.
#
# Feb 05 11:49:46 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
# Simulating 500.0 ms.
#
# Feb 05 11:49:48 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
# Simulating
NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 12:05:09 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 500
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 12:05:29 SimulationManager::run [Info]:
#     Simulation finished.
#
# Feb 05 12:05:29 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 12:05:29 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 1000
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 12:06:14 SimulationManager::run [Info]:
#     Simulation finished.
# Data will be written to: data_volt/15.86/trial_0/
#   Directory has been created.
#
#
# RNG seed: 55
# Total number of virtual processes: 10
# Creating neuronal populations.
#
# Feb 05 12:06:15 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Creating recording devices.
#   Creating voltmeters.
# Creating Poisson generators for background input.
# Connecting neuronal populations recurrently.
# NodeCollection(metadata=None, model=iaf_psc_exp, size=20683, first=1, last=20683)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5834, first=20684, last=26517)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=21915, first=26518, last=48432)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5479, first=48433, last=53911)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=4850, first=53912, last=58761)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=1065, first=58762, last=59826)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=14395, first=59827, last=74221)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=2948, first=74222, last=77169)
# Connecting Poisson generators for background input.
#
# Feb 05 12:06:22 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
# Simulating 500.0 ms.
#
# Feb 05 12:06:24 NodeManager::prepare_nodes [Info]: Simulating 1000.0 ms.
#
#     Preparing 77329 nodes for simulation.
#
# Feb 05 12:06:24 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 500
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 12:06:44 SimulationManager::run [Info]:
#     Simulation finished.
#
# Feb 05 12:06:44 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 12:06:44 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 1000
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 12:07:29 SimulationManager::run [Info]:
#     Simulation finished.
# Data will be written to: data_volt/16.38/trial_0/
#   Directory has been created.
#
#
# RNG seed: 55
# Total number of virtual processes: 10
# Creating neuronal populations.
#
# Feb 05 12:07:29 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Creating recording devices.
#   Creating voltmeters.
# Creating Poisson generators for background input.
# Connecting neuronal populations recurrently.
# NodeCollection(metadata=None, model=iaf_psc_exp, size=20683, first=1, last=20683)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5834, first=20684, last=26517)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=21915, first=26518, last=48432)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5479, first=48433, last=53911)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=4850, first=53912, last=58761)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=1065, first=58762, last=59826)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=14395, first=59827, last=74221)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=2948, first=74222, last=77169)
# Connecting Poisson generators for background input.
# Simulating 500.0 ms.
# Simulating 1000.0 ms.
#
# Feb 05 12:07:37 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 12:07:39 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 12:07:39 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 500
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 12:07:58 SimulationManager::run [Info]:
#     Simulation finished.
#
# Feb 05 12:07:58 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 12:07:58 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 1000
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 12:08:44 SimulationManager::run [Info]:
#     Simulation finished.
# Data will be written to: data_volt/16.9/trial_0/
#   Directory has been created.
#
#
# RNG seed: 55
# Total number of virtual processes: 10
# Creating neuronal populations.
#
# Feb 05 12:08:44 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Creating recording devices.
#   Creating voltmeters.
# Creating Poisson generators for background input.
# Connecting neuronal populations recurrently.
# NodeCollection(metadata=None, model=iaf_psc_exp, size=20683, first=1, last=20683)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5834, first=20684, last=26517)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=21915, first=26518, last=48432)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5479, first=48433, last=53911)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=4850, first=53912, last=58761)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=1065, first=58762, last=59826)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=14395, first=59827, last=74221)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=2948, first=74222, last=77169)
# Connecting Poisson generators for background input.
#
# Feb 05 12:08:52 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
# Simulating 500.0 ms.
# Simulating 1000.0 ms.
#
# Feb 05 12:08:54 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 12:08:54 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 500
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 12:09:14 SimulationManager::run [Info]:
#     Simulation finished.
#
# Feb 05 12:09:14 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 12:09:14 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 1000
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 12:10:00 SimulationManager::run [Info]:
#     Simulation finished.
# Data will be written to: data_volt/17.41/trial_0/
#   Directory has been created.
#
#
# RNG seed: 55
# Total number of virtual processes: 10
# Creating neuronal populations.
#
# Feb 05 12:10:00 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Creating recording devices.
#   Creating voltmeters.
# Creating Poisson generators for background input.
# Connecting neuronal populations recurrently.
# NodeCollection(metadata=None, model=iaf_psc_exp, size=20683, first=1, last=20683)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5834, first=20684, last=26517)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=21915, first=26518, last=48432)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5479, first=48433, last=53911)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=4850, first=53912, last=58761)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=1065, first=58762, last=59826)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=14395, first=59827, last=74221)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=2948, first=74222, last=77169)
# Connecting Poisson generators for background input.
#
# Feb 05 12:10:07 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
# Simulating 500.0 ms.
# Simulating 1000.0 ms.
#
# Feb 05 12:10:09 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 12:10:09 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 500
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 12:10:30 SimulationManager::run [Info]:
#     Simulation finished.
#
# Feb 05 12:10:30 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 12:10:30 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 1000
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 12:11:17 SimulationManager::run [Info]:
#     Simulation finished.
# Data will be written to: data_volt/17.93/trial_0/
#   Directory has been created.
#
#
# RNG seed: 55
# Total number of virtual processes: 10
# Creating neuronal populations.
#
# Feb 05 12:11:17 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Creating recording devices.
#   Creating voltmeters.
# Creating Poisson generators for background input.
# Connecting neuronal populations recurrently.
# NodeCollection(metadata=None, model=iaf_psc_exp, size=20683, first=1, last=20683)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5834, first=20684, last=26517)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=21915, first=26518, last=48432)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5479, first=48433, last=53911)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=4850, first=53912, last=58761)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=1065, first=58762, last=59826)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=14395, first=59827, last=74221)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=2948, first=74222, last=77169)
# Connecting Poisson generators for background input.
#
# Feb 05 12:11:25 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
# Simulating 500.0 ms.
#
# Simulating 1000.0 ms.
# Feb 05 12:11:27 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 12:11:27 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 500
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 12:11:48 SimulationManager::run [Info]:
#     Simulation finished.
#
# Feb 05 12:11:48 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 12:11:48 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 1000
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 12:12:34 SimulationManager::run [Info]:
#     Simulation finished.
# Data will be written to: data_volt/18.45/trial_0/
#   Directory has been created.
#
#
# RNG seed: 55
# Total number of virtual processes: 10
# Creating neuronal populations.
#
# Feb 05 12:12:35 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Creating recording devices.
#   Creating voltmeters.
# Creating Poisson generators for background input.
# Connecting neuronal populations recurrently.
# NodeCollection(metadata=None, model=iaf_psc_exp, size=20683, first=1, last=20683)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5834, first=20684, last=26517)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=21915, first=26518, last=48432)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5479, first=48433, last=53911)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=4850, first=53912, last=58761)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=1065, first=58762, last=59826)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=14395, first=59827, last=74221)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=2948, first=74222, last=77169)
# Connecting Poisson generators for background input.
#
# Feb 05 12:12:42 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
# Simulating 500.0 ms.
# Simulating 1000.0 ms.
#
# Feb 05 12:12:44 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 12:12:44 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 500
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 12:13:05 SimulationManager::run [Info]:
#     Simulation finished.
#
# Feb 05 12:13:05 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 12:13:05 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 1000
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 12:13:52 SimulationManager::run [Info]:
#     Simulation finished.
# Data will be written to: data_volt/18.97/trial_0/
#   Directory has been created.
#
#
# RNG seed: 55
# Total number of virtual processes: 10
# Creating neuronal populations.
#
# Feb 05 12:13:52 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Creating recording devices.
#   Creating voltmeters.
# Creating Poisson generators for background input.
# Connecting neuronal populations recurrently.
# NodeCollection(metadata=None, model=iaf_psc_exp, size=20683, first=1, last=20683)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5834, first=20684, last=26517)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=21915, first=26518, last=48432)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5479, first=48433, last=53911)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=4850, first=53912, last=58761)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=1065, first=58762, last=59826)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=14395, first=59827, last=74221)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=2948, first=74222, last=77169)
# Connecting Poisson generators for background input.
#
# Feb 05 12:13:59 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
# Simulating 500.0 ms.
#
# Feb 05 12:14:01 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
# Simulating 1000.0 ms.
#
# Feb 05 12:14:01 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 500
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 12:14:22 SimulationManager::run [Info]:
#     Simulation finished.
#
# Feb 05 12:14:22 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 12:14:22 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 1000
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 12:15:08 SimulationManager::run [Info]:
#     Simulation finished.
# Data will be written to: data_volt/19.48/trial_0/
#   Directory has been created.
#
#
# RNG seed: 55
# Total number of virtual processes: 10
# Creating neuronal populations.
#
# Feb 05 12:15:09 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Creating recording devices.
#   Creating voltmeters.
# Creating Poisson generators for background input.
# Connecting neuronal populations recurrently.
# NodeCollection(metadata=None, model=iaf_psc_exp, size=20683, first=1, last=20683)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5834, first=20684, last=26517)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=21915, first=26518, last=48432)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5479, first=48433, last=53911)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=4850, first=53912, last=58761)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=1065, first=58762, last=59826)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=14395, first=59827, last=74221)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=2948, first=74222, last=77169)
# Connecting Poisson generators for background input.
#
# Feb 05 12:15:16 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
# Simulating 500.0 ms.
#
# Feb 05 12:15:18 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
# Simulating 1000.0 ms.
#
# Feb 05 12:15:18 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 500
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 12:15:40 SimulationManager::run [Info]:
#     Simulation finished.
#
# Feb 05 12:15:40 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 12:15:40 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 1000
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 12:16:27 SimulationManager::run [Info]:
#     Simulation finished.
# Data will be written to: data_volt/20.0/trial_0/
#   Directory has been created.
#
#
# RNG seed: 55
# Total number of virtual processes: 10
# Creating neuronal populations.
#
# Feb 05 12:16:27 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Creating recording devices.
#   Creating voltmeters.
# Creating Poisson generators for background input.
# Connecting neuronal populations recurrently.
# NodeCollection(metadata=None, model=iaf_psc_exp, size=20683, first=1, last=20683)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5834, first=20684, last=26517)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=21915, first=26518, last=48432)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=5479, first=48433, last=53911)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=4850, first=53912, last=58761)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=1065, first=58762, last=59826)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=14395, first=59827, last=74221)
# NodeCollection(metadata=None, model=iaf_psc_exp, size=2948, first=74222, last=77169)
# Connecting Poisson generators for background input.
#
# Feb 05 12:16:36 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
# Simulating 500.0 ms.
#
# Feb 05 12:16:38 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 12:16:38 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 500
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 12:17:00 SimulationManager::run [Info]:
#     Simulation finished.
# Simulating 1000.0 ms.
#
# Feb 05 12:17:00 NodeManager::prepare_nodes [Info]:
#     Preparing 77329 nodes for simulation.
#
# Feb 05 12:17:00 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 77329
#     Simulation time (ms): 1000
#     Number of OpenMP threads: 10
#     Number of MPI processes: 1
#
# Feb 05 12:17:49 SimulationManager::run [Info]:
#     Simulation finished.
